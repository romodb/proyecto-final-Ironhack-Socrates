# %%
# Esto es solo para ver los Csv´s de forma comoda en Vscode
import pandas as pd
murcia_sucio = pd.read_csv('C:/Users/Ro/OneDrive/Escritorio/No se como llamarlo/Ironhack/Proyecto final/InventarioObrasArte-CARM-Transparencia.csv', delimiter=';', encoding = 'ISO-8859-1')

murcia_sucio
# Out:
#       Nï¿½_INVENTARIO                                             TITULO  \
# 0             1001489                   SERIE ESCENAS ESPAï¿½OLAS. VIII.
# 1             1001490                         SERIE ESCENAS ESPAï¿½OLAS.
# 2             1001491                      SERIE ESCENAS ESPAï¿½OLAS. X.
# 3             1001492                     SERIE ESCENAS ESPAï¿½OLAS. XI.
# 4             1001493                    SERIE ESCENAS ESPAï¿½OLAS. XII.
# ...               ...                                                ...
# 1635          2025508  LIMONES SOBRE MESA CON TAPETE ROJO Y SILLA MIMBRE
# 1636          2025509                       LIMONES SOBRE FONDO AMARILLO
# 1637          2025510                         FIGURA FEMENINA, TERRACOTA
# 1638          2038213                                CRUCE DE GEOMETRIAS
# 1639          2061200                                       SIN Tï¿½TULO
#
#                    NOMBRE_AUTOR FECHA_CREACION  FONDO  ANCHO  ALTO TECNICA  \
# 0               BAROJA, RICARDO            NaN    0.0   13.5  13.5     NaN
# 1               BAROJA, RICARDO            NaN    0.0   22.5  32.5     NaN
# 2               BAROJA, RICARDO            NaN    0.0   21.5  13.5     NaN
# 3               BAROJA, RICARDO            NaN    0.0   39.5  26.5     NaN
# 4               BAROJA, RICARDO            NaN    0.0   21.5  13.5     NaN
# ...                         ...            ...    ...    ...   ...     ...
# 1635         AVELLANEDA, MANUEL            NaN    0.0    0.0   0.0     NaN
# 1636          ALBACETE. ALFONSO            NaN    0.0    0.0   0.0     NaN
# 1637  ALBALADEJO GARCIA, GINESA            NaN    0.0    0.0   0.0     NaN
# 1638          JOSE MANUEL CIRIA            NaN    0.0    0.0   0.0     NaN
# 1639  CAMPILLO PARRAGA, ANTONIO            NaN    0.0    0.0   0.0     NaN
#
#             TIPO MATERIAL_BASE MATERIAL_SECUNDARIO    TEMATICA  \
# 0        PINTURA         PAPEL               TINTA  FIGURATIVO
# 1        PINTURA         PAPEL               TINTA  FIGURATIVO
# 2        PINTURA         PAPEL               TINTA  FIGURATIVO
# 3        PINTURA         PAPEL               TINTA  FIGURATIVO
# 4        PINTURA         PAPEL               TINTA  FIGURATIVO
# ...          ...           ...                 ...         ...
# 1635  SERIGRAFIA           NaN                 NaN         NaN
# 1636  SERIGRAFIA           NaN                 NaN         NaN
# 1637   ESCULTURA           NaN                 NaN         NaN
# 1638     PINTURA           NaN                OLEO         NaN
# 1639   ESCULTURA           NaN                 NaN         NaN
#
#       ESTADO_PATRIMONIAL                   USUARIO           ALTA  \
# 0       Alta patrimonial                       NaN    COMPRAVENTA
# 1     Cedido patrimonial  AYUNTAMIENTO DE LA UNION    COMPRAVENTA
# 2     Cedido patrimonial  AYUNTAMIENTO DE LA UNION    COMPRAVENTA
# 3     Cedido patrimonial  AYUNTAMIENTO DE LA UNION    COMPRAVENTA
# 4     Cedido patrimonial  AYUNTAMIENTO DE LA UNION    COMPRAVENTA
# ...                  ...                       ...            ...
# 1635    Alta patrimonial                       NaN    SIN DEFINIR
# 1636    Alta patrimonial                       NaN    SIN DEFINIR
# 1637    Alta patrimonial                       NaN    SIN DEFINIR
# 1638    Alta patrimonial                       NaN       DONACION
# 1639    Alta patrimonial                       NaN  INCORPORACION
#
#       VALOR_ADQUISICION
# 0                240.40
# 1                270.46
# 2                210.35
# 3                240.40
# 4                240.40
# ...                 ...
# 1635             500.00
# 1636             500.00
# 1637             150.00
# 1638           70000.00
# 1639           15000.00
#
# [1640 rows x 16 columns]

# %%
murcia_sucio.nunique()
# Out:
# Nï¿½_INVENTARIO        1640
# TITULO                 1092
# NOMBRE_AUTOR            470
# FECHA_CREACION          103
# FONDO                    62
# ANCHO                   221
# ALTO                    219
# TECNICA                  51
# TIPO                     19
# MATERIAL_BASE            27
# MATERIAL_SECUNDARIO      36
# TEMATICA                 17
# ESTADO_PATRIMONIAL        4
# USUARIO                  10
# ALTA                      6
# VALOR_ADQUISICION       284
# dtype: int64
